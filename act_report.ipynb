# %% [markdown]
# ## Report: act_report

# %%
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# WeRateDogs is a community on Twitter that shares pictures of dogs and rates them. Gathering information from over 2000 retweets, favorites, images, and texts I was able to come up with some insights.
#
# According to my findings, there is a high correlation between favorite_count and retweet-count. Meaning a tweet that is highly favored was also retweeted many times. Conversely the same is true, the more a tweet was retweeted, the more it was favored. The most retweeted image was a Labrador Retriever swimming in a pool video which was retweeted over 79,000 times, and was favored over 131,000 times, compared to the average retweet and favored count was 2,700, and 8,900 respectively.

# %%
Image(filename='fig1.png')

# %% [markdown]
# According to the machine learning model that recognized the dogs' breeds based on the tweeted pictures, the most tweeted breed was Golden Retriever, followed by Labrador Retriever, Pembroke Corgi, and Chihuahua.
#
# Although most tweeters did not provide their dog's life stage, out of the people that did provide that information 'Pupper'stage dogs were most tweeted about, followed by 'Doggo'.

# %%
Image(filename='fig2.png')

# %% [markdown]
# Out of the 1,500 tweets that provided the dog's name, Charlie, Cooper, Lucy and Oliver were the most frequent dog names. However most dogs' names were unique names such as Waffles, Comet, Kilo, Severus, and Maxaroni.
